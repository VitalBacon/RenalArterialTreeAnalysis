# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
from vis_utils import visualize_volume, load_volume
from scipy.ndimage import zoom

# %%
source_dir = './data/'
files = glob.glob(source_dir + '/*/*.raw')
files[0]
# Out:
# './data/P12/P12_60um_1333x443x864.raw'

# %%
# %%time
sample_volume = load_volume(files[0])
print(sample_volume.shape)
# Out:
# (864, 443, 1333)
# CPU times: user 16.5 ms, sys: 219 ms, total: 235 ms
# Wall time: 291 ms

# %%
visualize_volume(sample_volume, scale=0.4, primary_color=(0, 255, 0))

# %%
v_slice = sample_volume[530:532, :, :]
plt.imshow(v_slice[0], cmap='gray')
