# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import seaborn as sns
import pickle
from skimage import measure, segmentation, feature
from vis_utils import load_volume, VolumeVisualizer, ColorMapVisualizer
from scipy.ndimage import zoom
from skimage.morphology import skeletonize, skeletonize_3d, binary_dilation
from skimage import filters, morphology
from scipy.ndimage.filters import convolve, correlate
from scipy import signal
from skimage.filters import frangi, sato
from skimage.draw import line_nd
from PIL import Image
from queue import PriorityQueue

# %%
TREE_NAME = 'P12'

# %% [markdown]
# ## Loading DAG with stats

# %%
class Node:
    def __init__(self, coords):
        self.coords = coords
        self.edges = []
        self.data = {}
            
    def add_edge(self, edge):
        self.edges.append(edge)
        
    def get_neighbours(self):
        return [e.node_a if e.node_a.coords != self.coords else e.node_b for e in self.edges]
    
    def copy_without_edges(self):
        copied_node = Node(self.coords)
        copied_node.data = self.data
        return copied_node
    
    def __setitem__(self, key, value):
        self.data[key] = value
    
    def __getitem__(self, key):
        return self.data[key]
    
    def __hash__(self):
        return hash(self.coords)
    
    def __repr__(self):
        return f'Node {str(self.coords)}'
       
        
class Edge:
    def __init__(self, node_a, node_b):
        self.node_a = node_a
        self.node_b = node_b
        self.data = {}
        
    def __setitem__(self, key, value):
        self.data[key] = value
    
    def __getitem__(self, key):
        return self.data[key]
    
    def __repr__(self):
        return f'Edge {self.node_a.coords} -> {self.node_b.coords}'

    
class DAG:
    def __init__(self, root, volume_shape):
        self.root = root
        self.nodes = get_nodes_with_dfs(root)
        self.edges = get_edges_with_dfs(root)
        self.volume_shape = volume_shape
        self.data = {}
    
    def __setitem__(self, key, value):
        self.data[key] = value
    
    def __getitem__(self, key):
        return self.data[key]

def save_dag(dag, filename):
    with open(filename, 'wb') as output:
        pickle.dump(dag, output)
        

def load_dag(filename):
    with open(filename, 'rb') as input_:
        dag = pickle.load(input_)
        return dag

# %%
source_dir = './data/'
dag = load_dag(source_dir + TREE_NAME + '/dag-with-stats.pkl')

# %% [markdown]
# ## Utility visualisation functions

# %%
def visualize_addition(base, base_with_addition):
    base = (base.copy() > 0).astype(np.uint8)
    addition = (base_with_addition > 0).astype(np.uint8)
    addition[base == 1] = 0
    ColorMapVisualizer(base + addition * 4).visualize()
    
def visualize_lsd(lsd_mask):
    ColorMapVisualizer(lsd_mask.astype(np.uint8)).visualize()
    
def visualize_gradient(lsd_mask):
    ColorMapVisualizer(lsd_mask.astype(np.uint8)).visualize(gradient=True)
    
def visualize_mask_bin(mask):
    VolumeVisualizer((mask > 0).astype(np.uint8), binary=True).visualize()
    
def visualize_mask_non_bin(mask):
    VolumeVisualizer((mask > 0).astype(np.uint8) * 255, binary=False).visualize()
    
def visualize_skeleton(mask, visualize_mask=True, visualize_both_versions=False):
    skeleton = skeletonize((mask > 0).astype(np.uint8))
    if not visualize_mask or visualize_both_versions:
        VolumeVisualizer(skeleton, binary=True).visualize()
    if visualize_mask or visualize_both_versions:
        skeleton = skeleton.astype(np.uint8) * 4
        mask = (mask > 0).astype(np.uint8) * 3
        mask[skeleton != 0] = 0
        ColorMapVisualizer(skeleton + mask).visualize()

def visualize_ultimate(lsd, base_mask):
    visualize_lsd(lsd)
    visualize_mask_non_bin(lsd)
    visualize_addition(base_mask, lsd)
    visualize_skeleton(lsd, visualize_mask=True)

# %% [markdown]
# ## DAG visualization

# %%
def spherical_kernel(outer_radius, thickness=1, filled=True):    
    outer_sphere = morphology.ball(radius=outer_radius)
    if filled:
        return outer_sphere
    
    thickness = min(thickness, outer_radius)
    
    inner_radius = outer_radius - thickness
    inner_sphere = morphology.ball(radius=inner_radius)
    
    begin = outer_radius - inner_radius
    end = begin + inner_sphere.shape[0]
    outer_sphere[begin:end, begin:end, begin:end] -= inner_sphere
    return outer_sphere


def print_kernels(image, nodes, value):
    image = image.copy()
    max_kernel_radius = int(max([node['thiccness'] for node in nodes]))
    kernels = [spherical_kernel(radius) for radius in range(max_kernel_radius + 1)]
    
    padded_image = np.pad(image, max_kernel_radius)
    kernels_image = np.zeros(padded_image.shape)
    
    for node in nodes:
        x, y, z = (coord + max_kernel_radius for coord in node.coords)
        kernel_radius = int(node['thiccness'])
        kernel = kernels[kernel_radius]
        
        mask_slice = kernels_image[
            x-kernel_radius:x+kernel_radius + 1,
            y-kernel_radius:y+kernel_radius + 1,
            z-kernel_radius:z+kernel_radius + 1
        ]
        
        mask_slice[:] = np.logical_or(mask_slice, kernel)
            
    kernels_image = kernels_image[
        max_kernel_radius:-max_kernel_radius,
        max_kernel_radius:-max_kernel_radius,
        max_kernel_radius:-max_kernel_radius
    ]
    
    image[kernels_image == 1] = value
    return image


def draw_nodes(image, nodes, value=2):
    nodes_image = print_kernels(image, nodes, value)
    return nodes_image

    
def draw_edges(image, edges, value='mean_thiccness', interpolate=True):
    image = image.copy()

    for i, edge in enumerate(edges):
        if type(value) == str:
            fill_value = edge[value]
        else:
            fill_value = value
        
        if interpolate:
            image[line_nd(edge.node_a.coords, edge.node_b.coords)] = fill_value
        else:
            for v in edge['voxels']:
                image[tuple(v)] = fill_value
    return image


def draw_central_line(image, dag):
    image_with_edges = draw_edges(image, dag.edges, value=1, interpolate=False)
    for n in dag.nodes:
        for v in n['voxels']:
            image_with_edges[tuple(v)] = 1
    return image_with_edges

# %%
visualization = np.zeros(dag.volume_shape)
visualization = draw_nodes(visualization, dag.nodes, 25)
visualization = draw_edges(visualization, dag.edges, value='mean_thiccness')
visualize_gradient(visualization)

# %% [markdown]
# # Parameters presentation

# %% [markdown]
# ## Vessels length

# %%
lengths = [edge['length'] for edge in dag.edges]
plt.title('segments lengths')
plt.hist(lengths, bins=40)

plt.xlabel('length')
plt.ylabel('count')
plt.show()

# %%
print("Total vessels length is", sum(lengths))
# Out:
# Total vessels length is 31085.600872727333

# %%
print("Mean vessels length is", np.mean(lengths))
# Out:
# Mean vessels length is 14.116984955825302

# %% [markdown]
# ## Segments diameters

# %%
diameters = [edge['mean_thiccness'] for edge in dag.edges]
plt.title('segments diameters')
plt.hist(diameters, bins=int(np.max(diameters)))
plt.xlabel('diameters')
plt.ylabel('count')
plt.show()

# %%
print("Mean vessels diameter is", np.mean(diameters))
# Out:
# Mean vessels diameter is 2.090952295305367

# %% [markdown]
# ## Nodes degrees counts

# %%
print(np.unique([len(n.edges) for n in dag.nodes], return_counts=True))
print("Total number of branchings is", dag['branching_points'], 'or', len(dag.nodes), 'including leaves')
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([1171,    1,  907,  110,   13,    1]))
# Total number of branchings is 1031 or 2203 including leaves

# %% [markdown]
# ## Bifurcations angles

# %%
def draw_directions(image, edges, start_value=2, end_value=3, length=10):
    image = image.copy()

    for edge in edges:
        start_point = edge.node_a['centroid']
        end_point = start_point + length * edge['start_direction']
        end_point = np.maximum([0, 0, 0], end_point)
        end_point = np.minimum(np.array(image.shape) - 1, end_point)
        image[line_nd(start_point, end_point)] = start_value
        
        start_point = edge.node_b['centroid']
        end_point = start_point + length * edge['end_direction']
        end_point = np.maximum([0, 0, 0], end_point)
        end_point = np.minimum(np.array(image.shape) - 1, end_point)
        image[line_nd(start_point, end_point)] = end_value
        
    return image

img = np.zeros(dag.volume_shape)
img = draw_edges(img, dag.edges, value=2, interpolate=False)
img = draw_directions(img, dag.edges, start_value=4, end_value=3, length=15)
visualize_lsd(img)

# %%
angles = [edge['relative_angle'] for edge in dag.edges[1:]]
plt.title('bifurcation angles')
plt.hist(angles, bins=15)

plt.xlabel('angle')
plt.ylabel('count')
plt.show()

(1 / np.pi) * 180 # 1 is about 60 degrees
# Out:
# 57.29577951308232

# %% [markdown]
# ## Tortuosity (arc-chord ratio)

# %%
tortuosities = [edge['tortuosity'] for edge in dag.edges]
plt.title('segments tortuosities')
plt.hist(tortuosities, bins=30)

plt.xlabel('tortuosities')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Volume filled with vascular structure

# %%
print(dag['vascular_structure_volume'])
# Out:
# 392146

# %% [markdown]
# ## Fractal dimention

# %%
print(dag['fractal_dimension'])
# Out:
# 1.6273605145729009

# %% [markdown]
# ## Interstitial distance to the nearest vessel

# %%
visualization = np.zeros(dag.volume_shape)
visualization = draw_edges(visualization, dag.edges, value='interstitial_distance')
visualize_gradient(visualization)

# %%
interstitial_distance = [edge['interstitial_distance'] for edge in dag.edges[1:]]
plt.title('interstitial distances')
plt.hist(interstitial_distance, bins=50)

plt.xlabel('interstitial distances')
plt.ylabel('count')
plt.show()

# %%
print('Mean interstitial distance is', np.mean(interstitial_distance))
# Out:
# Mean interstitial distance is 8.184178699812762

# %% [markdown]
# ## Area covered by vascular network (overall size)

# %%
print(dag['vascular_network_projection_area'])
# Out:
# 63520

# %% [markdown]
# ## Vascular density

# %%
print('area covered by vascular network', dag['vascular_network_projection_area'])
print('area covered by networks explant', dag['projection_explant_area'])
print('vascular density', dag['vascular_density'])
# Out:
# area covered by vascular network 63520
# area covered by networks explant 180867
# vascular density 0.3511972886153914

# %% [markdown]
# ## Lacunarity

# %%
print('Lacunarity is', dag['lacunarity'], '(average for boxes with sizes 10, 30, 50, 70, 90, 110, 130, 150)')
# Out:
# Lacunarity is 1.5020559959491009 (average for boxes with sizes 10, 30, 50, 70, 90, 110, 130, 150)

# %% [markdown]
# ## Branching index - measurement of sprouting activity

# %%
print('Branching index is', dag['branchings_points_per_pixel'], 'branches per pixel')
# Out:
# Branching index is 0.01623110831234257 branches per pixel

# %% [markdown]
# # Generations

# %%
visualization = np.zeros(dag.volume_shape)
visualization = draw_edges(visualization, dag.edges, interpolate=False, value='generation')
visualize_lsd(visualization)

# %%
points = np.concatenate([e['voxels2d'] for e in dag.edges])
colors = np.concatenate([np.full(len(e['voxels2d']), fill_value=e['generation']) for e in dag.edges])
proper_indices = colors <= np.max(colors) - 1
points = points[proper_indices]
colors = colors[proper_indices]

plt.figure(figsize=(15, 10))
plt.scatter(points[:, 0], points[:, 1], c=colors, s=9, cmap='gist_rainbow')

# %% [markdown]
# ## Statistics by generation

# %%
generations_number = np.max([edge['generation'] for edge in dag.edges])
edges_counts_dict = {gen: 0 for gen in range(1, generations_number + 1)}
for edge in dag.edges:
    edges_counts_dict[edge['generation']] += 1

plt.figure(figsize=(7, 4))
plt.bar(edges_counts_dict.keys(), height=edges_counts_dict.values())
plt.title('Edges counts per generation')
plt.xlabel('generation')
plt.ylabel('number of edges')
plt.show()

plt.figure(figsize=(7, 4))
plt.bar(list(edges_counts_dict.keys())[:-1], height=list(edges_counts_dict.values())[:-1])
plt.title('Edges counts per generation')
plt.xlabel('generation')
plt.ylabel('number of edges')
plt.show()

# %%
def get_edge_stat_by_generation(dag, stat, ommit_root_edge=False):
    generations_number = np.max([edge['generation'] for edge in dag.edges])
    stat_dict = {gen: [] for gen in range(1, generations_number)}
    
    if ommit_root_edge:
        dag_edges = dag.edges[1:]
    else:
        dag_edges = dag.edges
        
    for edge in dag_edges:
        if edge['generation'] == generations_number:
            continue
        stat_dict[edge['generation']].append(edge[stat])
    return stat_dict

# %%
thiccness_dict = get_edge_stat_by_generation(dag, 'length')
mean_thiccness = [np.mean(v) for v in thiccness_dict.values()]
generation_indices = list(thiccness_dict.keys())

plt.figure(figsize=(7, 4))
plt.bar(generation_indices, height=mean_thiccness)
plt.title('mean length of edges per generation')
plt.xlabel('generation')
plt.ylabel('mean length')
plt.show()

# %%
thiccness_dict = get_edge_stat_by_generation(dag, 'mean_thiccness')
mean_thiccness = [np.mean(v) for v in thiccness_dict.values()]
generation_indices = list(thiccness_dict.keys())

plt.figure(figsize=(7, 4))
plt.bar(generation_indices, height=mean_thiccness)
plt.title('mean thickness of edges per generation')
plt.xlabel('generation')
plt.ylabel('mean thickness')
plt.show()

# %%
thiccness_dict = get_edge_stat_by_generation(dag, 'relative_angle', ommit_root_edge=True)
mean_thiccness = [np.mean(v) for v in thiccness_dict.values()]
generation_indices = list(thiccness_dict.keys())

plt.figure(figsize=(7, 4))
plt.bar(generation_indices, height=mean_thiccness)
plt.title('mean bifurcation angle of edges per generation')
plt.xlabel('generation')
plt.ylabel('mean bifurcation angle')
plt.show()
# Out:
# /home/jakub/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jakub/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
thiccness_dict = get_edge_stat_by_generation(dag, 'tortuosity')
mean_thiccness = [np.mean(v) for v in thiccness_dict.values()]
generation_indices = list(thiccness_dict.keys())

plt.figure(figsize=(7, 4))
plt.bar(generation_indices, height=mean_thiccness)
plt.title('mean tortuosity of edges per generation')
plt.xlabel('generation')
plt.ylabel('mean tortuosity')
plt.show()

# %%
thiccness_dict = get_edge_stat_by_generation(dag, 'interstitial_distance')
mean_thiccness = [np.mean(v) for v in thiccness_dict.values()]
generation_indices = list(thiccness_dict.keys())

plt.figure(figsize=(7, 4))
plt.bar(generation_indices, height=mean_thiccness)
plt.title('mean interstitial distance of edges per generation')
plt.xlabel('generation')
plt.ylabel('mean interstitial distance')
plt.show()

# %% [markdown]
# ## Statistics comparison

# %%
lengths = [edge['length'] for edge in dag.edges]
tortuosities = [edge['tortuosity'] for edge in dag.edges]
plt.title('relationship between tortuosity and vessel length')
plt.scatter(lengths, tortuosities, s=0.7)

plt.xlabel('vessel length')
plt.ylabel('vessel tortuosity')
plt.show()

# %% [markdown]
# ### edges statistics dataframe

# %%
stats = ['length', 'mean_thiccness', 'relative_angle', 'tortuosity', 'interstitial_distance']

df_dict = {}
for stat_name in stats:
    stat = [edge[stat_name] for edge in dag.edges]
    df_dict[stat_name] = stat
    
edges_stats_df = pd.DataFrame.from_dict(df_dict)
edges_stats_df.head()
# Out:
#        length  mean_thiccness  relative_angle  tortuosity  \
# 0   18.641729       11.461538             NaN    1.086592
# 1  101.738807       11.234568        1.411441    1.105494
# 2   78.921002        9.169492        1.161281    1.044866
# 3   22.044067        8.937500        1.056009    1.050910
# 4   14.312410        7.100000        0.853091    1.024933
#
#    interstitial_distance
# 0                    inf
# 1              63.998891
# 2              41.872672
# 3              12.492832
# 4              10.145707

# %%
corr = edges_stats_df.dropna().corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# <style  type="text/css" >
#     #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col1 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col3 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col4 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col0 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col4 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col1 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col3 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col0 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col2 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col4 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col0 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col1 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col2 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col3 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >length</th>        <th class="col_heading level0 col1" >mean_thiccness</th>        <th class="col_heading level0 col2" >relative_angle</th>        <th class="col_heading level0 col3" >tortuosity</th>        <th class="col_heading level0 col4" >interstitial_distance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4level0_row0" class="row_heading level0 row0" >length</th>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col0" class="data row0 col0" >1.000</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col1" class="data row0 col1" >0.231</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col2" class="data row0 col2" >-0.018</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col3" class="data row0 col3" >0.177</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row0_col4" class="data row0 col4" >0.597</td>
#             </tr>
#             <tr>
#                         <th id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4level0_row1" class="row_heading level0 row1" >mean_thiccness</th>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col0" class="data row1 col0" >0.231</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col1" class="data row1 col1" >1.000</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col2" class="data row1 col2" >-0.021</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col3" class="data row1 col3" >-0.100</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row1_col4" class="data row1 col4" >0.487</td>
#             </tr>
#             <tr>
#                         <th id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4level0_row2" class="row_heading level0 row2" >relative_angle</th>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col0" class="data row2 col0" >-0.018</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col1" class="data row2 col1" >-0.021</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col2" class="data row2 col2" >1.000</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col3" class="data row2 col3" >0.219</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row2_col4" class="data row2 col4" >0.032</td>
#             </tr>
#             <tr>
#                         <th id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4level0_row3" class="row_heading level0 row3" >tortuosity</th>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col0" class="data row3 col0" >0.177</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col1" class="data row3 col1" >-0.100</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col2" class="data row3 col2" >0.219</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col3" class="data row3 col3" >1.000</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row3_col4" class="data row3 col4" >0.086</td>
#             </tr>
#             <tr>
#                         <th id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4level0_row4" class="row_heading level0 row4" >interstitial_distance</th>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col0" class="data row4 col0" >0.597</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col1" class="data row4 col1" >0.487</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col2" class="data row4 col2" >0.032</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col3" class="data row4 col3" >0.086</td>
#                         <td id="T_66795e3e_e6b5_11ea_a2ca_2d182ad83ea4row4_col4" class="data row4 col4" >1.000</td>
#             </tr>
#     </tbody></table>

# %%
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(edges_stats_df.dropna())
